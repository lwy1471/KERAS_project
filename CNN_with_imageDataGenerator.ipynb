# %%
#패키지 Import
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

#랜덤 시드 고정
np.random.seed(3)

#데이터 생성
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=10, width_shift_range=0.2, height_shift_range=0.2, shear_range=0.7, zoom_range=[0.9,2.2], horizontal_flip=True, vertical_flip=True, fill_mode='nearest')

train_generator = train_datagen.flow_from_directory('./dataset/handwriting_shape/train', target_size=(24,24), batch_size=3, class_mode='categorical')
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory('./dataset/handwriting_shape/test', target_size=(24,24), batch_size=3, class_mode='categorical')

#모델 구성
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(24,24,3)))
model.add(Conv2D(64,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(3, activation='softmax'))

#모델 학습 설정
model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

#모델 학습
model.fit_generator(train_generator, steps_per_epoch=15, epochs=50, validation_data=test_generator, validation_steps=5)

#모델 평가
print("--Evaluate--")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

#모델 사용
print("--Predict--")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Using TensorFlow backend.
# Found 45 images belonging to 3 classes.
# Found 15 images belonging to 3 classes.
# Epoch 1/50
# 15/15 [==============================] - 2s 105ms/step - loss: 1.2446 - acc: 0.4000 - val_loss: 1.1032 - val_acc: 0.3333
# Epoch 2/50
# 15/15 [==============================] - 1s 52ms/step - loss: 1.1016 - acc: 0.4000 - val_loss: 1.0945 - val_acc: 0.3333
# Epoch 3/50
# 15/15 [==============================] - 1s 54ms/step - loss: 1.0668 - acc: 0.4667 - val_loss: 1.0912 - val_acc: 0.3333
# Epoch 4/50
# 15/15 [==============================] - 1s 55ms/step - loss: 1.0428 - acc: 0.4889 - val_loss: 1.0086 - val_acc: 0.4000
# Epoch 5/50
# 15/15 [==============================] - 1s 52ms/step - loss: 0.9656 - acc: 0.5556 - val_loss: 1.0582 - val_acc: 0.6667
# Epoch 6/50
# 15/15 [==============================] - 1s 58ms/step - loss: 0.8678 - acc: 0.6444 - val_loss: 1.2899 - val_acc: 0.3333
# Epoch 7/50
# 15/15 [==============================] - 1s 53ms/step - loss: 0.7652 - acc: 0.6444 - val_loss: 2.0282 - val_acc: 0.3333
# Epoch 8/50
# 15/15 [==============================] - 1s 53ms/step - loss: 0.7387 - acc: 0.7333 - val_loss: 2.1943 - val_acc: 0.3333
# Epoch 9/50
# 15/15 [==============================] - 1s 53ms/step - loss: 0.8044 - acc: 0.6222 - val_loss: 1.8792 - val_acc: 0.3333
# Epoch 10/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.9653 - acc: 0.5111 - val_loss: 2.0549 - val_acc: 0.4667
# Epoch 11/50
# 15/15 [==============================] - 1s 53ms/step - loss: 0.5935 - acc: 0.7778 - val_loss: 1.2990 - val_acc: 0.5333
# Epoch 12/50
# Epoch 34/50
# 15/15 [==============================] - 1s 58ms/step - loss: 0.4619 - acc: 0.8444 - val_loss: 0.3121 - val_acc: 0.9333
# Epoch 35/50
# 15/15 [==============================] - 1s 58ms/step - loss: 0.5659 - acc: 0.8000 - val_loss: 0.3053 - val_acc: 0.9333
# Epoch 36/50
# 15/15 [==============================] - 1s 56ms/step - loss: 0.2494 - acc: 0.9111 - val_loss: 0.2343 - val_acc: 0.9333
# Epoch 37/50
# 15/15 [==============================] - 1s 60ms/step - loss: 0.4632 - acc: 0.8000 - val_loss: 0.1696 - val_acc: 0.9333
# Epoch 38/50
# 15/15 [==============================] - 1s 59ms/step - loss: 0.3309 - acc: 0.8667 - val_loss: 0.2118 - val_acc: 0.8667
# Epoch 39/50
# 15/15 [==============================] - 1s 58ms/step - loss: 0.4363 - acc: 0.8444 - val_loss: 0.4094 - val_acc: 0.8667
# Epoch 40/50
# 15/15 [==============================] - 1s 64ms/step - loss: 0.2574 - acc: 0.8889 - val_loss: 0.0885 - val_acc: 1.0000
# Epoch 41/50
# 15/15 [==============================] - 1s 70ms/step - loss: 0.3768 - acc: 0.8667 - val_loss: 0.3822 - val_acc: 0.8667
# Epoch 42/50
# 15/15 [==============================] - 1s 60ms/step - loss: 0.3892 - acc: 0.8222 - val_loss: 0.1987 - val_acc: 0.9333
# Epoch 43/50
# 15/15 [==============================] - 1s 56ms/step - loss: 0.2023 - acc: 0.9333 - val_loss: 0.8213 - val_acc: 0.6000
# Epoch 44/50
# 15/15 [==============================] - 1s 57ms/step - loss: 0.3716 - acc: 0.8222 - val_loss: 0.2943 - val_acc: 0.8667
# Epoch 45/50
# 15/15 [==============================] - 1s 56ms/step - loss: 0.4276 - acc: 0.8222 - val_loss: 0.0985 - val_acc: 0.9333
# Epoch 46/50
# 15/15 [==============================] - 1s 65ms/step - loss: 0.3887 - acc: 0.8444 - val_loss: 0.0278 - val_acc: 1.0000
# Epoch 47/50
# 15/15 [==============================] - 1s 58ms/step - loss: 0.3425 - acc: 0.8889 - val_loss: 0.1468 - val_acc: 1.0000
# Epoch 48/50
# 15/15 [==============================] - 1s 57ms/step - loss: 0.3350 - acc: 0.9111 - val_loss: 0.1847 - val_acc: 0.9333
# Epoch 49/50
# 15/15 [==============================] - 1s 59ms/step - loss: 0.3101 - acc: 0.8889 - val_loss: 0.2167 - val_acc: 0.8667
# Epoch 50/50
# 15/15 [==============================] - 1s 66ms/step - loss: 0.4418 - acc: 0.8667 - val_loss: 0.6020 - val_acc: 0.8000
# --Evaluate--
# acc: 80.00%
# --Predict--
# {'rectangle': 1, 'circle': 0, 'triangle': 2}
# [[0.997 0.003 0.000]
#  [0.315 0.567 0.118]
#  [0.708 0.117 0.176]
#  [0.005 0.995 0.000]
#  [0.000 1.000 0.000]
#  [0.963 0.037 0.000]
#  [0.007 0.966 0.026]
#  [0.000 1.000 0.000]
#  [0.317 0.169 0.514]
#  [0.990 0.010 0.000]
#  [0.993 0.007 0.000]
#  [0.003 0.997 0.000]
#  [0.332 0.210 0.458]
#  [0.005 0.995 0.000]
#  [0.997 0.003 0.000]]
